# %% [markdown]
# # Missão individual
#
# Escolha um arquivo:
#
# - `clientes_sujo.csv`
# - `filmes_sujo.csv`
#
# Repita o processo:
#
# 1. Abra o arquivo.
# 2. Investigue.
# 3. Trate nulos.
# 4. Remova duplicados.
# 5. Padronize textos.
# 6. Corrija tipos.
# 7. Corrija valores inválidos.
# 8. Valide.
# 9. Salve uma versão tratada.

# %% [markdown]
# ## 1. Importando o Pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Abrindo o dataset

# %%
df = pd.read_csv("filmes_sujo.csv")
df.head()
# Out:
#              Filme   Ano             Genero  NotaIMDb  DuracaoMin Infantil
# 0     Interestelar  2014  Ficção Científica       8.7         169      Não
# 1        Toy Story  1995          animação        8.3          81      Sim
# 2         Parasita  2019              Drama       8.5         132      Não
# 3  Divertida Mente  2015           Animação       NaN          95      Sim
# 4           Matrix  1999  Ficção Científica       8.7         136      Não

# %% [markdown]
# ## 3. Investigação inicial
#
# Ainda não corrija nada. Primeiro descubra os problemas.

# %%
df.shape
# Out:
# (11, 6)

# %%
df.columns
# Out:
# Index(['Filme', 'Ano', 'Genero', 'NotaIMDb', 'DuracaoMin', 'Infantil'], dtype='object')

# %%
df.dtypes
# Out:
# Filme          object
# Ano            object
# Genero         object
# NotaIMDb      float64
# DuracaoMin      int64
# Infantil       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Filme       11 non-null     object
#  1   Ano         11 non-null     object
#  2   Genero      11 non-null     object
#  3   NotaIMDb    10 non-null     float64
#  4   DuracaoMin  11 non-null     int64
#  5   Infantil    11 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 660.0+ bytes

# %%
df.describe()
# Out:
#         NotaIMDb  DuracaoMin
# count  10.000000   11.000000
# mean    8.390000  114.909091
# std     0.310734   75.516163
# min     7.900000  -90.000000
# 25%     8.225000   97.500000
# 50%     8.450000  132.000000
# 75%     8.675000  165.500000
# max     8.700000  180.000000

# %%
df.isnull().sum()
# Out:
# Filme         0
# Ano           0
# Genero        0
# NotaIMDb      1
# DuracaoMin    0
# Infantil      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 4. Tratando valores nulos

# %%
nota = df["NotaIMDb"].mean()
print("NotaIMDb:", nota)
# Out:
# NotaIMDb: 8.39

# %%
duracao = df["DuracaoMin"].mean()
print("DuracaoMin", duracao)
# Out:
# DuracaoMin 129.4

# %%
df["NotaIMDb"] = df["NotaIMDb"].fillna(nota)

# %%
df.isnull().sum()
# Out:
# Filme         0
# Ano           0
# Genero        0
# NotaIMDb      0
# DuracaoMin    0
# Infantil      0
# dtype: int64

# %% [markdown]
# ## 5. Removendo duplicados

# %%
df[df.duplicated()]
# Out:
#            Filme   Ano             Genero  NotaIMDb  DuracaoMin Infantil
# 10  Interestelar  2014  Ficção Científica       8.7         169      Não

# %%
df = df.drop_duplicates()

print("Duplicados restantes:", df.duplicated().sum())
# Out:
# Duplicados restantes: 0

# %% [markdown]
# ## 6. Padronizando textos

# %%
f["Genero"] = df["Genero"].astype(str).str.strip().str.title()
# Out:
# /tmp/ipykernel_523/3246830845.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Genero"] = df["Genero"].astype(str).str.strip().str.title()

# %% [markdown]
# ## 7. Corrigindo tipos de dados

# %%
df['Ano'] = df['Ano'].replace('2023', 2023)

df['Ano'] = pd.to_numeric(df['Ano'], errors='coerce')

df['Ano'] = pd.to_datetime(
    df['Ano'],
    format='%Y',
    errors='coerce'
)

# %%
df['Ano'] = pd.to_datetime(df['Ano'], errors='coerce').dt.year
df.dtypes
# Out:
# /tmp/ipykernel_523/2814148072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ano'] = pd.to_datetime(df['Ano'], errors='coerce').dt.year
# Filme          object
# Ano             int32
# Genero         object
# NotaIMDb      float64
# DuracaoMin      int64
# Infantil       object
# dtype: object

# %% [markdown]
# ## 8. Localizando valores inválidos

# %%
df[df["DuracaoMin"] < 0]
# Out:
#    Filme   Ano   Genero  NotaIMDb  DuracaoMin Infantil
# 5  Shrek  2001  Comédia       7.9         -90      Sim

# %% [markdown]
# ## 9. Corrigindo valores inválidos
#
# As decisões abaixo são didáticas. Em projetos reais, consulte as regras do negócio.

# %%
df.loc[5, "DuracaoMin"] = 129.4
# Out:
# /tmp/ipykernel_523/2009395972.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '129.4' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[5, "DuracaoMin"] = 129.4

# %%
df.loc[8, "Infantil"] = 'Sim'

# %% [markdown]
# ## 10. Validação final

# %%
print("Valores nulos:")
print(df.isnull().sum())

print("\nDuplicados:", df.duplicated().sum())
# Out:
# Valores nulos:
# Filme         0
# Ano           0
# Genero        0
# NotaIMDb      0
# DuracaoMin    0
# Infantil      0
# dtype: int64
#
# Duplicados: 0

# %%
df.describe()
# Out:
#         NotaIMDb  DuracaoMin
# count  10.000000   10.000000
# mean    8.359000  129.400000
# std     0.291222   33.413903
# min     7.900000   81.000000
# 25%     8.225000  102.250000
# 50%     8.395000  131.000000
# 75%     8.575000  155.500000
# max     8.700000  180.000000

# %%
df.head(10)
# Out:
#              Filme                      Ano             Genero  NotaIMDb  \
# 0     Interestelar                     2014  Ficção Científica      8.70
# 1        Toy Story                     1995           Animação      8.30
# 2         Parasita                     2019              Drama      8.50
# 3  Divertida Mente                     2015           Animação      8.39
# 4           Matrix                     1999  Ficção Científica      8.70
# 5            Shrek                     2001            Comédia      7.90
# 6      Oppenheimer  dois mil e vinte e três              Drama      8.40
# 7           Avatar                     2009  Ficção Científica      7.90
# 8  Procurando Nemo                     2003           Animação      8.20
# 9   Cidade de Deus                     2002              Drama      8.60
#
#    DuracaoMin Infantil
# 0         169      Não
# 1          81      Sim
# 2         132      Não
# 3          95      Sim
# 4         136      Não
# 5         109      Sim
# 6         180      Não
# 7         162      Não
# 8         100      Sim
# 9         130      Não

# %% [markdown]
# ## 11. Salvando o dataset tratado

# %%
df.to_csv("filmes_tratado.csv", index=False)


df['Ano'] = df['Ano'].replace('dois mil e vinte e três', 2023)

df['Ano'] = pd.to_numeric(df['Ano'], errors='coerce')

df.dtypes
# Out:
# Filme          object
# Ano             int32
# Genero         object
# NotaIMDb      float64
# DuracaoMin    float64
# Infantil       object
# dtype: object

# %%
df['Ano'] = df['Ano'].dt.year
display(df.head())
# Out:
#              Filme   Ano             Genero  NotaIMDb  DuracaoMin Infantil
# 0     Interestelar  2014  Ficção Científica      8.70       169.0      Não
# 1        Toy Story  1995           Animação      8.30        81.0      Sim
# 2         Parasita  2019              Drama      8.50       132.0      Não
# 3  Divertida Mente  2015           Animação      8.39        95.0      Sim
# 4           Matrix  1999  Ficção Científica      8.70       136.0      Não

# %%
df
# Out:
#              Filme   Ano             Genero  NotaIMDb  DuracaoMin Infantil
# 0     Interestelar  2014  Ficção Científica      8.70       169.0      Não
# 1        Toy Story  1995           Animação      8.30        81.0      Sim
# 2         Parasita  2019              Drama      8.50       132.0      Não
# 3  Divertida Mente  2015           Animação      8.39        95.0      Sim
# 4           Matrix  1999  Ficção Científica      8.70       136.0      Não
# 5            Shrek  2001            Comédia      7.90       129.4      Sim
# 6      Oppenheimer  2023              Drama      8.40       180.0      Não
# 7           Avatar  2009  Ficção Científica      7.90       162.0      Não
# 8  Procurando Nemo  2003           Animação      8.20       100.0      Sim
# 9   Cidade de Deus  2002              Drama      8.60       130.0      Não
